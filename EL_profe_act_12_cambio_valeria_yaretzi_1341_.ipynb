# %% [markdown]
# <a href="https://colab.research.google.com/github/VALERIAMARTINEZ128/calcular-cambio-if-else-/blob/main/EL_profe_act_12_cambio_valeria_yaretzi_1341_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### valeria yaretzi lopez NC = 2530805128**1341**
# #### NL = 32  fecha 26/marzo/2026
# ### calculando el cambio usando if else
# ### mirara diagrama de flujo
# <img src="https://raw.githubusercontent.com/VALERIAMARTINEZ128/calcular-cambio-if-else-/refs/heads/main/cambio%202.jpg" width="200" height="200">
# ## las variables
# 1. CP --> costo del producto
# 2. CD ---> Cantidad de dinero
# 3. Cambio
#
# ## formulas
# $cambio = CD - CP$
#
# ## Diagrama de flujo lucidchart
# <img src="https://raw.githubusercontent.com/VALERIAMARTINEZ128/calcular-cambio-if-else-/refs/heads/main/DF%20%20if%20else%20cambio%202.png" width="300" height="500">

# %%
# para cuando es verdadero
# calculando el cambio uando if else
# datos de entrada CD,CP
# mostar cambio si es falso
# si es verdadero mostar No  alcanza
CP = float(input("ingrese el costo del producto: "))
CD = float(input("ingrese la cantidad de dinero: "))
if CD >= CP:
    cambio = CD - CP
    print("No alcanza")

else:
    cambio = CD - CP
    print("el cambio es: ",cambio)
    print("fin del programa")
    print("programa realizado por valeria yretzi NL = 32 ")
# Out:
# ingrese el costo del producto: 500
# ingrese la cantidad de dinero: 400
# no alcanza
# fin del programa
# programa realizado por valeria yretzi NL = 32

# %%
# para cuando es falso
# calculando el cambio uando if else
# datos de entrada CD,CP
# mostar cambio si es falso
# si es verdadero mostar No  alcanza
CP = float(input("ingrese el costo del producto: "))
CD = float(input("ingrese la cantidad de dinero: "))
if CD >= CP:
    cambio = CD - CP
    print("el cambio es: ",cambio)
else:
    print("no alcanza")
    print("fin del programa")
    print("programa realizado por valeria yretzi NL = 32 ")
# Out:
# ingrese el costo del producto: 250
# ingrese la cantidad de dinero: 300
# el cambio es:  50.0

# %% [markdown]
# ## Relacion del codigo de flujo
# <img src="https://raw.githubusercontent.com/VALERIAMARTINEZ128/calcular-cambio-if-else-/refs/heads/main/tldraw%20codigo%20DF.png" width="800" height="500">
